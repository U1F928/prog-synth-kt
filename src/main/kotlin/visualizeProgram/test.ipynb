// %%
DISPLAY(
    HTML(
      """
      <!doctype html>
<html>
<head>
    <meta charset="utf-8">
    <script src="https://unpkg.com/@antv/g6@5/dist/g6.min.js"></script>
</head>
<body style="margin:0">
Hello world !!!!
<div id="mount" style="width:30vw;height:30vh"></div>
<script>

    const { Graph } = G6;
    const graph = new Graph({
      container: 'mount',
      width: innerWidth,
      height: innerHeight,
      layout: { type: 'force' },
    });
    graph.setData({
      nodes: [{ id: 'a' }, { id: 'b' }, { id: 'c' }],
      edges: [{ source: 'a', target: 'b' }, { source: 'b', target: 'c' }],
    });
    graph.render();
</script>
</body>
</html>

      """
    )

)
// Out:
//       <!doctype html>
// <html>
// <head>
//     <meta charset="utf-8">
//     <script src="https://unpkg.com/@antv/g6@5/dist/g6.min.js"></script>
// </head>
// <body style="margin:0">
// Hello world !!!!
// <div id="mount" style="width:30vw;height:30vh"></div>
// <script>
//
//     const { Graph } = G6;
//     const graph = new Graph({
//       container: 'mount',
//       width: innerWidth,
//       height: innerHeight,
//       layout: { type: 'force' },
//     });
//     graph.setData({
//       nodes: [{ id: 'a' }, { id: 'b' }, { id: 'c' }],
//       edges: [{ source: 'a', target: 'b' }, { source: 'b', target: 'c' }],
//     });
//     graph.render();
// </script>
// </body>
// </html>

// %%
HTML("""
    <h3>Here's a kitten from Wikipedia 🐾</h3>
    <img src="https://upload.wikimedia.org/wikipedia/commons/3/3a/Cat03.jpg"
         alt="Cute kitten"
         width="300"
         style="border-radius: 12px; box-shadow: 0 0 10px rgba(0,0,0,0.2);" />
""")
// Out:
//     <h3>Here's a kitten from Wikipedia 🐾</h3>
//     <img src="https://upload.wikimedia.org/wikipedia/commons/3/3a/Cat03.jpg"
//          alt="Cute kitten"
//          width="300"
//          style="border-radius: 12px; box-shadow: 0 0 10px rgba(0,0,0,0.2);" />

// %%
HTML("""
    <!-- Container for the graph -->
    <div id="cy" style="width: 400px; height: 300px; border: 1px solid #ccc;"></div>

    <!-- Load Cytoscape.js from CDN -->
    <script src="https://unpkg.com/cytoscape/dist/cytoscape.min.js"></script>

    <script>
        // Wait a bit to ensure Cytoscape.js has loaded
        setTimeout(() => {
            const cy = cytoscape({
                container: document.getElementById('cy'),

                elements: [
                    { data: { id: 'a', label: 'Node A' } },
                    { data: { id: 'b', label: 'Node B' } },
                    { data: { id: 'c', label: 'Node C' } },
                    { data: { id: 'ab', source: 'a', target: 'b' } },
                    { data: { id: 'bc', source: 'b', target: 'c' } }
                ],

                layout: { name: 'circle' },

                style: [
                    {
                        selector: 'node',
                        style: {
                            'background-color': '#61bffc',
                            'label': 'data(label)',
                            'color': '#333',
                            'text-valign': 'center',
                            'text-halign': 'center',
                            'font-size': '10px'
                        }
                    },
                    {
                        selector: 'edge',
                        style: {
                            'width': 2,
                            'line-color': '#ccc',
                            'target-arrow-color': '#ccc',
                            'target-arrow-shape': 'triangle'
                        }
                    }
                ]
            });
        }, 200);
    </script>
""")
// Out:
//     <!-- Container for the graph -->
//     <div id="cy" style="width: 400px; height: 300px; border: 1px solid #ccc;"></div>
//
//     <!-- Load Cytoscape.js from CDN -->
//     <script src="https://unpkg.com/cytoscape/dist/cytoscape.min.js"></script>
//
//     <script>
//         // Wait a bit to ensure Cytoscape.js has loaded
//         setTimeout(() => {
//             const cy = cytoscape({
//                 container: document.getElementById('cy'),
//
//                 elements: [
//                     { data: { id: 'a', label: 'Node A' } },
//                     { data: { id: 'b', label: 'Node B' } },
//                     { data: { id: 'c', label: 'Node C' } },
//                     { data: { id: 'ab', source: 'a', target: 'b' } },
//                     { data: { id: 'bc', source: 'b', target: 'c' } }
//                 ],
//
//                 layout: { name: 'circle' },
//
//                 style: [
//                     {
// ...

// %%
%use lets-plot

%use lets-plot

// Define nodes and edges
        data class Node(val id: String, val label: String)
data class Edge(val source: String, val target: String)

val nodes = listOf(
    Node("a", "Node A"),
    Node("b", "Node B"),
    Node("c", "Node C"),
    Node("d", "Node D")
)

val edges = listOf(
    Edge("a", "b"),
    Edge("b", "c"),
    Edge("c", "d"),
    Edge("d", "a")
)

// Compute circular layout
val centerX = 0.0
val centerY = 0.0
val radius = 1.0
val angleStep = 2 * Math.PI / nodes.size

val positions = nodes.mapIndexed { i, node ->
    val angle = i * angleStep
    node.id to Pair(radius * kotlin.math.cos(angle), radius * kotlin.math.sin(angle))
}.toMap()

// Prepare data for edges (segments)
val edgeData = mapOf(
    "x" to edges.map { positions[it.source]!!.first },
    "y" to edges.map { positions[it.source]!!.second },
    "xend" to edges.map { positions[it.target]!!.first },
    "yend" to edges.map { positions[it.target]!!.second }
)

// Prepare data for nodes
val nodeData = mapOf(
    "x" to nodes.map { positions[it.id]!!.first },
    "y" to nodes.map { positions[it.id]!!.second },
    "label" to nodes.map { it.label }
)

// Build the plot
val plot = letsPlot() +
        geomSegment(edgeData ) +
        geomPoint(nodeData) +
        geomText(nodeData)

plot
// Out:
//    <div id="NBQtSj"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
// ...
